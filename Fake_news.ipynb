# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')
fake = pd.read_csv('Fake.csv')
true['label'] = 1
fake['label'] = 0

# %%
news = pd.concat([true, fake] , axis = 0)
news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = news.drop(['title','subject','date'] , axis = 1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  WASHINGTON (Reuters) - The head of a conservat...      1
# 1  WASHINGTON (Reuters) - Transgender people will...      1
# 2  WASHINGTON (Reuters) - The special counsel inv...      1
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      1
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      1

# %%
news = news.sample(frac =1)

# %%
news.head()
# Out:
#                                                     text  label
# 10286  Establishment Republican Reince Priebus is gon...      0
# 10645     Delta Air Lines and Bank of America became ...      0
# 18265  BANGKOK (Reuters) - A Thai criminal court has ...      1
# 15279  GAZA (Reuters) - Gaza s merchants and consumer...      1
# 17590  HANOI (Reuters) - At least 54 people died and ...      1

# %%
news.reset_index(inplace =True)

# %%
news = news.drop(['index'] , axis =1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Establishment Republican Reince Priebus is gon...      0
# 1     Delta Air Lines and Bank of America became ...      0
# 2  BANGKOK (Reuters) - A Thai criminal court has ...      1
# 3  GAZA (Reuters) - Gaza s merchants and consumer...      1
# 4  HANOI (Reuters) - At least 54 people died and ...      1

# %%
import re

# %%
def wordopt(text) :
  text = text.lower()
  text = re.sub(r'https?://\S+|www\.\S' ,'',text)
  text = re.sub(r'<.*?>' ,'',text)
  text = re.sub(r'[^\w\s]','',text)
  text = re.sub(r'\d' ,'',text)
  text = re.sub(r'\n' ,' ',text)
  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        establishment republican reince priebus is gon...
# 1           delta air lines and bank of america became ...
# 2        bangkok reuters  a thai criminal court has iss...
# 3        gaza reuters  gaza s merchants and consumers a...
# 4        hanoi reuters  at least  people died and  went...
#                                ...
# 44893    kiev reuters  ukrainian president petro porosh...
# 44894    on tuesday democratic senator dianne feinstein...
# 44895    this is pricelessdonald trump has not even tak...
# 44896    the story below from the liberal new york time...
# 44897    aden reuters  security forces in the southern ...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score, classification_report

# %%
from numpy.random.mtrand import random
x_train , x_test ,y_train , y_test = train_test_split(x,y,test_size= 0.3,random_state=42)

# %%
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(x_train)
xv_test = vectorizer.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9888641425389755

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7094
#            1       0.98      0.99      0.99      6376
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(xv_test,y_test)
# Out:
# 0.9961395694135116

# %%
pred_dtc = dtc.predict(xv_test)
print(classification_report(y_test , pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7094
#            1       1.00      1.00      1.00      6376
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(random_state=0)
gbc.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=0)
rfc.fit(xv_train,y_train)
predict_rfc = rfc.predict(xv_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7094
#            1       0.98      0.99      0.99      6376
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
rfc.score(xv_test,y_test)
# Out:
# 0.987750556792873

# %%
print(classification_report(y_test,predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7094
#            1       0.98      0.99      0.99      6376
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470
